# %%
from datapreparator import DataPreparator
import yaml
from pathlib import Path
root_path = Path()
import pandas as pd

df = pd.read_json('../../../data/Books_10k.jsonl', lines=True)
# Load YAML config
root_path = Path()  # or just Path() if you run from project root
config_path = root_path / '../config/dataprep_config.yaml'

# --- Load YAML config properly ---
with open(config_path, "r", encoding="utf-8") as f:
    config = yaml.safe_load(f)   # safe_load is recommended (prevents code execution)


# Initialize preparator from YAML
prep = DataPreparator(config)

# Clean and create label column
df_prepared = prep.transform(df)

# %%
from transformation import TextTfidfTransformer
from sklearn.model_selection import train_test_split

config_transf_path = root_path / '../config/transformation_config.yaml'
# --- Load YAML config properly ---
with open(config_transf_path, "r", encoding="utf-8") as f:
    config_transf = yaml.safe_load(f)   # safe_load is recommended (prevents code execution)

# Step 2 — Transform to TF-IDF
tfidf_tr = TextTfidfTransformer(config_transf)

TEXT_COL, LABEL_COL = "sentence", "sentiment"

X_train, X_test, y_train, y_test = train_test_split(
    df_prepared[TEXT_COL], df_prepared[LABEL_COL], test_size=0.2, random_state=42, stratify=df_prepared[LABEL_COL]
)

X = tfidf_tr.fit_transform(X_train)
y = y_train

X_t = tfidf_tr.transform(X_test)
y_t = y_test

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

lgr = LogisticRegression(max_iter=1000, class_weight="balanced")
lgr.fit(X,y)
preds = lgr.predict(X_t)
print("Score:", lgr.score(X_t,y_t))
print()
print(classification_report(y_test, preds))

# %%
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
# Out:
# 0.5925818392973797

# %%
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.61      0.62      4744
#            1       0.40      0.42      0.41      3116
#            2       0.67      0.67      0.67      5917
#
#     accuracy                           0.59     13777
#    macro avg       0.57      0.57      0.57     13777
# weighted avg       0.60      0.59      0.59     13777

# %%
df[df['verified_purchase']==False]
# Out:
#       rating                                              title  \
# 3          1                       Written From a Lens of Fear.
# 15         1  badly and hastily written, without explanation...
# 19         1                                         worst ever
# 23         1  Another story where women have no interests be...
# 24         1                  Catchy promises, little delivery.
# ...      ...                                                ...
# 9994       2                                        Bewildering
# 9996       2                                          Confusing
# 9997       2                       The Case of the Missing Plot
# 9998       2    Poorly written biography of a fascinating woman
# 9999       2                             Dr von Igelfeld afield
#
#                                                    text images        asin  \
# 3     Only read and believe things you want to see c...     []  0929385225
# 15    My interest is mostly on deep and reinforcemen...     []  1484228650
# 19    worst woods book i've read. and i have read th...     []  0399169113
# 23    I just finished this book and was sorely disap...     []  1501196022
# 24    I breezed through this book really fast, more ...     []  B00NIFXWH2
# ...                                                 ...    ...         ...
# 9994  I've heard of the 'Mary Celeste', including va...     []  0385533500
# 9996  The story takes place over the past fifty year...     []  0544077792
# 9997  I picked this up because the premise sounded i...     []  B0048EL7YW
# 9998  Calling Julia Child 'remarkable' is an underst...     []  0307272222
# 9999  Professor Dr Moritz-Maria von Igelfeld leaves ...     []  1400095093
#
#      parent_asin                       user_id               timestamp  \
# 3     0929385225  AG2L7H23R5LLKDKLBEF2Q3L2MVDA 2021-04-05 01:16:52.328
# 15    1484228650  AEIOIVFNO6QX7OYOJNPRKQEWMPGA 2019-06-19 15:13:27.397
# 19    0399169113  AFIFCPYKA56DJ26GZ6TKSN5KR6BQ 2014-08-25 19:49:38.000
# 23    1501196022  AHSDSJIJUZVBJXQJIKFJVCAOPGYA 2022-03-07 10:27:55.130
# 24    B00NIFXWH2  AHSDSJIJUZVBJXQJIKFJVCAOPGYA 2018-09-04 17:46:06.617
# ...          ...                           ...                     ...
# 9994  0385533500  AHXWUCTMVBQXDVMDFPA3NO43QF2Q 2013-12-30 20:31:58.000
# 9996  0544077792  AHXWUCTMVBQXDVMDFPA3NO43QF2Q 2013-03-28 02:06:55.000
# 9997  B0048EL7YW  AHXWUCTMVBQXDVMDFPA3NO43QF2Q 2012-12-05 19:07:48.000
# 9998  0307272222  AHXWUCTMVBQXDVMDFPA3NO43QF2Q 2012-12-01 19:41:44.000
# 9999  1400095093  AHXWUCTMVBQXDVMDFPA3NO43QF2Q 2012-11-17 23:52:38.000
#
#       helpful_vote  verified_purchase
# 3                0              False
# 15               1              False
# 19               3              False
# 23               0              False
# 24               0              False
# ...            ...                ...
# 9994            10              False
# 9996             1              False
# 9997             0              False
# 9998            37              False
# 9999             0              False
#
# [5228 rows x 10 columns]

# %%
df[df['user_id']=='AETE7Y3DZT6BLMWA6U27ADJDZ4LA']
# Out:
#       rating                                              title  \
# 3612       5                                     Wonderful Read
# 3613       5                                 Good Read / Series
# 3614       5                                Great Read / Author
# 3615       5                                     Excellent Read
# 3616       5                                         GREAT READ
# 3617       5                                  EDGE OF SEAT READ
# 3618       5               STELLAR READ BEAUTIFULLY ILLUSTRATED
# 3619       5  BEAUTIFULLY CREATED * SUMPTUOUS RECIPIES * SOU...
# 3620       5                                         Five Stars
# 3621       5                                         Five Stars
#
#                                                    text images        asin  \
# 3612                          Great book in this series     []  0553391984
# 3613                         Great part of this series.     []  0778369870
# 3614                                         Great Read     []  B00HTJUN7K
# 3615                        Excellent Read. Great Price     []  0778361012
# 3616     Stellar Writing. Great Price from this vendor.     []  0778319024
# 3617                   Excellent Read . Fantastic Price     []  0778319180
# 3618  Stellar Read & Explanations of Jewish Holy Day...     []  0983532710
# 3619  Treated Myself to this Adeena’ s Latest Cookbo...     []  0525533451
# 3620                                      100% positive     []  1451660847
# 3621                                      100% positive     []  159077034X
#
#      parent_asin                       user_id               timestamp  \
# 3612  0553391984  AETE7Y3DZT6BLMWA6U27ADJDZ4LA 2021-01-18 22:43:08.160
# 3613  0778369870  AETE7Y3DZT6BLMWA6U27ADJDZ4LA 2021-01-18 22:29:47.862
# 3614  B00HTJUN7K  AETE7Y3DZT6BLMWA6U27ADJDZ4LA 2020-12-17 22:09:37.040
# 3615  0778361012  AETE7Y3DZT6BLMWA6U27ADJDZ4LA 2020-11-14 20:11:10.878
# 3616  0778319024  AETE7Y3DZT6BLMWA6U27ADJDZ4LA 2020-11-14 20:09:55.465
# 3617  0778319180  AETE7Y3DZT6BLMWA6U27ADJDZ4LA 2020-11-14 20:08:12.286
# 3618  0983532710  AETE7Y3DZT6BLMWA6U27ADJDZ4LA 2020-11-04 19:39:58.041
# 3619  0525533451  AETE7Y3DZT6BLMWA6U27ADJDZ4LA 2020-08-09 01:43:55.028
# 3620  1451660847  AETE7Y3DZT6BLMWA6U27ADJDZ4LA 2015-01-01 20:23:42.000
# 3621  159077034X  AETE7Y3DZT6BLMWA6U27ADJDZ4LA 2015-01-01 20:23:27.000
#
#       helpful_vote  verified_purchase
# 3612             0               True
# 3613             0               True
# 3614             0               True
# 3615             0               True
# 3616             0               True
# 3617             0               True
# 3618             0               True
# 3619             3               True
# 3620             0               True
# 3621             0               True

# %%
df[df.duplicated(subset=['text', 'user_id'])].sort_values('text')
# Out:
#       rating                                              title  \
# 3621       5                                         Five Stars
# 4705       4                   Language Arts 2nd Grade Workbook
# 1906       1                                           One Star
# 1905       1                                           One Star
# 2270       5                           very, very well received
# ...      ...                                                ...
# 9232       2  no weaving together==just a bunch of interesti...
# 9739       2                                           terrible
# 3958       5                                              great
# 3957       5                                              great
# 3999       5                  you won't be disappointed in this
#
#                                                    text images        asin  \
# 3621                                      100% positive     []  159077034X
# 4705  A Skill Practice workbook for 2nd graders.  It...     []  1483841707
# 1906                        Book damaged. Unacceptable.     []  1619635186
# 1905                        Book damaged. Unacceptable.     []  0147516145
# 2270  Bought these for daughter (33 years old) who i...     []  1937994775
# ...                                                 ...    ...         ...
# 9232  so disappointed in this series. the writer is ...     []  0553381695
# 9739                                           terrible     []  B00H25FJ20
# 3958    this is a wonderful book, everything I expected     []  0396081614
# 3957    this is a wonderful book, everything I expected     []  1101982454
# 3999  you won't be disappointed in this. the seller ...     []  1460974425
#
#      parent_asin                       user_id               timestamp  \
# 3621  159077034X  AETE7Y3DZT6BLMWA6U27ADJDZ4LA 2015-01-01 20:23:27.000
# 4705  1483841707  AG7JSIKUQPSL5AAPRDRKDNWM4U2A 2018-04-11 12:19:19.952
# 1906  1619635186  AHMWFC6ZWFFJKSIPMCAOTOWGE7HA 2017-05-25 00:01:55.000
# 1905  0147516145  AHMWFC6ZWFFJKSIPMCAOTOWGE7HA 2017-05-25 00:02:14.000
# 2270  1937994775  AFZUK3MTBIBEDQOPAK3OATUOUKLA 2016-01-13 21:44:25.000
# ...          ...                           ...                     ...
# 9232  0553381695  AEGT45MQAI7LJ5IQRHEUFRQMKGIA 2013-08-10 17:54:26.000
# 9739  B00H25FJ20  AGYCUB73SSFFXPWLK7MJR6NUGWOA 2016-02-03 20:34:27.000
# 3958  0396081614  AGUWL2R2JFLC3K65HLD6AHJV3KBA 2020-09-02 21:19:42.037
# 3957  1101982454  AGUWL2R2JFLC3K65HLD6AHJV3KBA 2020-09-02 21:20:57.158
# 3999  1460974425  AGUWL2R2JFLC3K65HLD6AHJV3KBA 2014-06-25 01:00:41.000
#
#       helpful_vote  verified_purchase
# 3621             0               True
# 4705             0              False
# 1906             0               True
# 1905             0               True
# 2270             0               True
# ...            ...                ...
# 9232             0               True
# 9739             0               True
# 3958             0               True
# 3957             0               True
# 3999             0               True
#
# [208 rows x 10 columns]

# %%
df[df['asin']=='B0BMT2PL6G']
# Out:
#      rating                title  \
# 697       1  Deserves ZERO stars
# 699       1  Deserves ZERO stars
#
#                                                   text images        asin  \
# 697  Poorly written.  Not much useful information. ...     []  B0BMT2PL6G
# 699  Poorly written.  Not much useful information. ...     []  B0BMT2PL6G
#
#     parent_asin                       user_id               timestamp  \
# 697  B0BMT2PL6G  AFZGIAQOQORI5HDS22LMNLE422OA 2023-02-21 19:38:52.495
# 699  B0BMT2PL6G  AFZGIAQOQORI5HDS22LMNLE422OA 2023-02-21 19:38:52.495
#
#      helpful_vote  verified_purchase
# 697             0               True
# 699             0               True

# %%
df[df.duplicated(subset=['text'])].sort_values('text')
# Out:
#       rating                              title  \
# 3621       5                         Five Stars
# 4705       4   Language Arts 2nd Grade Workbook
# 1906       1                           One Star
# 1905       1                           One Star
# 9795       2                       Plain. Cheap
# ...      ...                                ...
# 9233       2        no cohesion or interweaving
# 9739       2                           terrible
# 3958       5                              great
# 3957       5                              great
# 3999       5  you won't be disappointed in this
#
#                                                    text images        asin  \
# 3621                                      100% positive     []  159077034X
# 4705  A Skill Practice workbook for 2nd graders.  It...     []  1483841707
# 1906                        Book damaged. Unacceptable.     []  1619635186
# 1905                        Book damaged. Unacceptable.     []  0147516145
# 9795                                             Boring     []  1780553331
# ...                                                 ...    ...         ...
# 9233  so disappointed in this series. the writer is ...     []  055358202X
# 9739                                           terrible     []  B00H25FJ20
# 3958    this is a wonderful book, everything I expected     []  0396081614
# 3957    this is a wonderful book, everything I expected     []  1101982454
# 3999  you won't be disappointed in this. the seller ...     []  1460974425
#
#      parent_asin                       user_id               timestamp  \
# 3621  159077034X  AETE7Y3DZT6BLMWA6U27ADJDZ4LA 2015-01-01 20:23:27.000
# 4705  1483841707  AG7JSIKUQPSL5AAPRDRKDNWM4U2A 2018-04-11 12:19:19.952
# 1906  1619635186  AHMWFC6ZWFFJKSIPMCAOTOWGE7HA 2017-05-25 00:01:55.000
# 1905  0147516145  AHMWFC6ZWFFJKSIPMCAOTOWGE7HA 2017-05-25 00:02:14.000
# 9795  1780553331  AHU2QGPRV4UIPYLVHEHUHB2YHIVQ 2019-01-10 08:29:41.964
# ...          ...                           ...                     ...
# 9233  055358202X  AEGT45MQAI7LJ5IQRHEUFRQMKGIA 2013-08-10 17:53:22.000
# 9739  B00H25FJ20  AGYCUB73SSFFXPWLK7MJR6NUGWOA 2016-02-03 20:34:27.000
# 3958  0396081614  AGUWL2R2JFLC3K65HLD6AHJV3KBA 2020-09-02 21:19:42.037
# 3957  1101982454  AGUWL2R2JFLC3K65HLD6AHJV3KBA 2020-09-02 21:20:57.158
# 3999  1460974425  AGUWL2R2JFLC3K65HLD6AHJV3KBA 2014-06-25 01:00:41.000
#
#       helpful_vote  verified_purchase
# 3621             0               True
# 4705             0              False
# 1906             0               True
# 1905             0               True
# 9795             0               True
# ...            ...                ...
# 9233             3               True
# 9739             0               True
# 3958             0               True
# 3957             0               True
# 3999             0               True
#
# [230 rows x 10 columns]

# %%
orig_df
# Out:
#        rating                                              title  \
# 0           1      Not a watercolor book! Seems like copies imo.
# 22          1                             Missing the sketch pad
# 24          1           Crease down entire side of every page!!!
# 25          1                       Written From a Lens of Fear.
# 28          1  Good if your little one is unsure/scared of th...
# ...       ...                                                ...
# 68828       2                            Worth every cent I paid
# 68832       2                                          Confusing
# 68840       2                       The Case of the Missing Plot
# 68849       2    Poorly written biography of a fascinating woman
# 68875       2                             Dr von Igelfeld afield
#
#                                                     text  \
# 0      It is definitely not a watercolor book.  The p...
# 22     Missing the sketch pad. Even worse I realized ...
# 24     Every page has a crease running the entire len...
# 25     Only read and believe things you want to see c...
# 28     My little one just likes doctors so I thought ...
# ...                                                  ...
# 68828  Apparently there are readers who enjoyed this ...
# 68832  The story takes place over the past fifty year...
# 68840  I picked this up because the premise sounded i...
# 68849  Calling Julia Child 'remarkable' is an underst...
# 68875  Professor Dr Moritz-Maria von Igelfeld leaves ...
#
#                                                   images        asin  \
# 0      [{'small_image_url': 'https://m.media-amazon.c...  B09BGPFTDB
# 22                                                    []  1631591290
# 24     [{'small_image_url': 'https://images-na.ssl-im...  1780671067
# 25                                                    []  0929385225
# 28                                                    []  0593426452
# ...                                                  ...         ...
# 68828                                                 []  B00AAGZ1S0
# 68832                                                 []  0544077792
# 68840                                                 []  B0048EL7YW
# 68849                                                 []  0307272222
# 68875                                                 []  1400095093
#
#       parent_asin                       user_id               timestamp  \
# 0      B09BGPFTDB  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ 2022-01-17 06:06:38.485
# 22     1631591290  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ 2021-08-05 04:28:04.910
# 24     1780671067  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ 2021-01-26 01:07:03.325
# 25     0929385225  AG2L7H23R5LLKDKLBEF2Q3L2MVDA 2021-04-05 01:16:52.328
# 28     0593426452  AE74DYR3QUGVPZJ3P7RFWBGIX7XQ 2022-03-18 04:24:46.871
# ...           ...                           ...                     ...
# 68828  B00AAGZ1S0  AHXWUCTMVBQXDVMDFPA3NO43QF2Q 2013-06-24 00:18:07.000
# 68832  0544077792  AHXWUCTMVBQXDVMDFPA3NO43QF2Q 2013-03-28 02:06:55.000
# 68840  B0048EL7YW  AHXWUCTMVBQXDVMDFPA3NO43QF2Q 2012-12-05 19:07:48.000
# 68849  0307272222  AHXWUCTMVBQXDVMDFPA3NO43QF2Q 2012-12-01 19:41:44.000
# 68875  1400095093  AHXWUCTMVBQXDVMDFPA3NO43QF2Q 2012-11-17 23:52:38.000
#
#        helpful_vote  verified_purchase  sentiment  \
# 0                 0               True          0
# 22                0               True          0
# 24                2               True          0
# 25                0              False          0
# 28                1               True          0
# ...             ...                ...        ...
# 68828             2               True          0
# 68832             1              False          0
# 68840             0              False          0
# 68849            37              False          0
# 68875             0              False          0
#
#                                                 sentence
# 0                It is definitely not a watercolor book.
# 22                               Missing the sketch pad.
# 24     Every page has a crease running the entire len...
# 25     Only read and believe things you want to see c...
# 28     My little one just likes doctors so I thought ...
# ...                                                  ...
# 68828  Apparently there are readers who enjoyed this ...
# 68832  The story takes place over the past fifty year...
# 68840  I picked this up because the premise sounded i...
# 68849  Calling Julia Child 'remarkable' is an underst...
# 68875  Professor Dr Moritz-Maria von Igelfeld leaves ...
#
# [9777 rows x 12 columns]

# %%
TEXT_COL = 'text'

orig_df = df_prepared.drop_duplicates(subset=['text', 'sentiment'])
X_train, X_test, y_train, y_test = train_test_split(
    orig_df[TEXT_COL], orig_df[LABEL_COL], test_size=0.2, random_state=42, stratify=orig_df[LABEL_COL]
)
